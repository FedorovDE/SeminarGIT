# %% [markdown]
# <a href="https://colab.research.google.com/github/FedorovDE/SeminarGIT/blob/main/Exersise/Exersise%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Это мое первое текстовое поле

# %%
print ('Это мое первое текстовое поле')
# Out:
# Это мое первое текстовое поле
